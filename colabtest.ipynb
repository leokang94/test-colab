# %%
ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Mar  4 03:26 ./
# drwxr-xr-x 1 root root 4096 Mar  4 03:19 ../
# drwxr-xr-x 4 root root 4096 Mar  3 01:39 .config/
# drwx------ 5 root root 4096 Mar  4 03:26 drive/
# drwxr-xr-x 1 root root 4096 Mar  3 01:40 sample_data/
